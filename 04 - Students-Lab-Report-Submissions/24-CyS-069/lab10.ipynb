# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

data = {
    'Email_Length': [120, 300, 150, 500, 80, 700, 200, 50],
    'Links_Count': [0, 5, 1, 10, 0, 12, 2, 0],
    'Contains_Offer': [0, 1, 0, 1, 0, 1, 0, 0],
    'Spam': [0, 1, 0, 1, 0, 1, 0, 0]
}

df = pd.DataFrame(data)

X = df[['Email_Length', 'Links_Count', 'Contains_Offer']]
y = df['Spam']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
# c:\Users\HP 840\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\HP 840\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

data = {
    'Weather': ['Sunny', 'Sunny', 'Overcast', 'Rainy', 'Rainy', 'Rainy',
                'Overcast', 'Sunny', 'Sunny', 'Rainy'],
    'Temperature': ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool',
                    'Mild', 'Cool', 'Mild', 'Mild'],
    'Humidity': ['High', 'High', 'High', 'High', 'Normal', 'Normal',
                 'Normal', 'High', 'Normal', 'High'],
    'Wind': ['Weak', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong',
             'Strong', 'Weak', 'Weak', 'Strong'],
    'Play': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No',
             'Yes', 'No', 'Yes', 'No']
}

df = pd.DataFrame(data)

encoder = LabelEncoder()
for col in df.columns:
    df[col] = encoder.fit_transform(df[col])

X = df[['Weather', 'Temperature', 'Humidity', 'Wind']]
y = df['Play']
dt_model = DecisionTreeClassifier(criterion='entropy')
dt_model.fit(X, y)

plt.figure(figsize=(12, 6))
plot_tree(dt_model, feature_names=X.columns, filled=True)
plt.show()

sample = [[0, 2, 1, 0]]  
prediction = dt_model.predict(sample)
print("Prediction (0 = No, 1 = Yes):", prediction)
# Out:
# Prediction (0 = No, 1 = Yes): [1]
# c:\Users\HP 840\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
